# %% [markdown]
# # Convert HuggingFace models to GGUF format
#
# This notebook converts HuggingFace models to GGUF format that's supported
# by llama.cpp. The notebook also supports downloading a model from HuggingFace
# directly by setting the `download_model_id` param in Substratus.

# %% [markdown]
# Load the params provided by substratus

# %%
import json
from pathlib import Path

params = {}
params_path = Path("/content/params.json")
if params_path.is_file():
    with params_path.open("r", encoding="UTF-8") as params_file:
        params = json.load(params_file)
if 'name' not in params:
    raise Exception("Missing required param `name`")

name = params["name"]

output_path = params.get("output_path", "/content/model")
params
# Out:
# {'name': 'test',
#  'download_model_id': 'lmsys/vicuna-13b-v1.5',
#  'quantize': 'Q2_K, Q4_K_M'}

# %% [markdown]
# Download the model from huggingFace if `download_model_id` params is set. Otherwise
# this expects HuggingFace model to be present at `/content/saved-model`

# %%
from huggingface_hub import snapshot_download

model_path = "/content/saved-model"

model_id = params.get("download_model_id")
if model_id:
    model_path = "/content/downloaded-model"
    snapshot_download(repo_id=model_id, local_dir=model_path,
                      local_dir_use_symlinks=False, revision="main")
# Out:
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/192 [00:00<?, ?B/s]
# Downloading (…)df14bcd3a6/README.md:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# Downloading (…)14bcd3a6/config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# Downloading (…)cd3a6/.gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/33.4k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00003.bin:   0%|          | 0.00/6.18G [00:00<?, ?B/s]
# Downloading (…)l-00001-of-00003.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00003.bin:   0%|          | 0.00/9.90G [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]

# %% [markdown]
# Convert the model to GGUF 16 bit so it can be further used with `llama.cpp/example/quantize` tool

# %%
import os
# have to use this hack otherwise the python3 command won't work
os.environ["MODEL_PATH"] = model_path
os.environ["OUTFILE"] = f"{output_path}/{name}-f16.gguf"

! mkdir -p {output_path}
! ls -lash {model_path}
! python3 /content/llama.cpp/convert.py \
  --outfile $OUTFILE \
  --outtype f16 $MODEL_PATH

! ls -lash {output_path}

# %% [markdown]
# Optionally create additional quantized models

# %%
! quantize -h
# Out:
# usage: quantize [--help] [--allow-requantize] [--leave-output-tensor] model-f32.gguf [model-quant.gguf] type [nthreads]
#
#   --allow-requantize: Allows requantizing tensors that have already been quantized. Warning: This can severely reduce quality compared to quantizing from 16bit or 32bit
#   --leave-output-tensor: Will leave output.weight un(re)quantized. Increases model size but may also increase quality, especially when requantizing
#
# Allowed quantization types:
#    2  or  Q4_0   :  3.56G, +0.2166 ppl @ LLaMA-v1-7B
#    3  or  Q4_1   :  3.90G, +0.1585 ppl @ LLaMA-v1-7B
#    8  or  Q5_0   :  4.33G, +0.0683 ppl @ LLaMA-v1-7B
#    9  or  Q5_1   :  4.70G, +0.0349 ppl @ LLaMA-v1-7B
#   10  or  Q2_K   :  2.63G, +0.6717 ppl @ LLaMA-v1-7B
#   12  or  Q3_K   : alias for Q3_K_M
#   11  or  Q3_K_S :  2.75G, +0.5551 ppl @ LLaMA-v1-7B
#   12  or  Q3_K_M :  3.07G, +0.2496 ppl @ LLaMA-v1-7B
#   13  or  Q3_K_L :  3.35G, +0.1764 ppl @ LLaMA-v1-7B
#   15  or  Q4_K   : alias for Q4_K_M
#   14  or  Q4_K_S :  3.59G, +0.0992 ppl @ LLaMA-v1-7B
#   15  or  Q4_K_M :  3.80G, +0.0532 ppl @ LLaMA-v1-7B
#   17  or  Q5_K   : alias for Q5_K_M
#   16  or  Q5_K_S :  4.33G, +0.0400 ppl @ LLaMA-v1-7B
#   17  or  Q5_K_M :  4.45G, +0.0122 ppl @ LLaMA-v1-7B
#   18  or  Q6_K   :  5.15G, -0.0008 ppl @ LLaMA-v1-7B
#    7  or  Q8_0   :  6.70G, +0.0004 ppl @ LLaMA-v1-7B
#    1  or  F16    : 13.00G              @ 7B
#    0  or  F32    : 26.00G              @ 7B
#           COPY   : only copy tensors, no quantizing

# %%
quantize = params.get("quantize")
if quantize:
    quantize = [q.strip() for q in quantize.split(",")]
    for quantize_type in quantize:
        filename = f"{output_path}/{name}-{quantize_type}.gguf"
        os.environ["filename"] = filename
        os.environ["quantize_type"] = quantize_type
        print(f"Running {quantize_type} quantization and writing to {filename}")
        ! quantize $OUTFILE $filename $quantize_type
    ! ls -lash {output_path}
# Out:
# main: build = 1154 (3358c38)
# main: quantizing '/content/model/test-f16.gguf' to '/content/model/test-Q2_K.gguf' as Q2_K
# llama_model_loader: loaded meta data with 18 key-value pairs and 363 tensors from /content/model/test-f16.gguf (version GGUF V2 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight f16      [  5120, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:              blk.0.attn_q.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    2:              blk.0.attn_k.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_v.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    4:         blk.0.attn_output.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_gate.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor    6:              blk.0.ffn_up.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor    7:            blk.0.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor    8:           blk.0.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor    9:            blk.0.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   10:              blk.1.attn_q.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   11:              blk.1.attn_k.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   12:              blk.1.attn_v.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   13:         blk.1.attn_output.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   14:            blk.1.ffn_gate.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   15:              blk.1.ffn_up.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   16:            blk.1.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   17:           blk.1.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   18:            blk.1.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   19:              blk.2.attn_q.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   20:              blk.2.attn_k.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   21:              blk.2.attn_v.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   22:         blk.2.attn_output.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   23:            blk.2.ffn_gate.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   24:              blk.2.ffn_up.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   25:            blk.2.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   26:           blk.2.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   27:            blk.2.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   28:              blk.3.attn_q.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   29:              blk.3.attn_k.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.3.attn_v.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   31:         blk.3.attn_output.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   32:            blk.3.ffn_gate.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   33:              blk.3.ffn_up.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   34:            blk.3.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tens
  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  322:           blk.35.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  323:          blk.35.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  324:           blk.35.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  325:             blk.36.attn_q.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  326:             blk.36.attn_k.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  327:             blk.36.attn_v.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  328:        blk.36.attn_output.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  329:           blk.36.ffn_gate.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  330:             blk.36.ffn_up.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  331:           blk.36.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  332:          blk.36.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  333:           blk.36.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  334:             blk.37.attn_q.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  335:             blk.37.attn_k.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  336:             blk.37.attn_v.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  337:        blk.37.attn_output.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  338:           blk.37.ffn_gate.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  339:             blk.37.ffn_up.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  340:           blk.37.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  341:          blk.37.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  342:           blk.37.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  343:             blk.38.attn_q.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  344:             blk.38.attn_k.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  345:             blk.38.attn_v.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  346:        blk.38.attn_output.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  347:           blk.38.ffn_gate.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  348:             blk.38.ffn_up.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  349:           blk.38.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  350:          blk.38.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  351:           blk.38.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  352:             blk.39.attn_q.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  353:             blk.39.attn_k.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  354:             blk.39.attn_v.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  355:        blk.39.attn_output.weight f16      [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  356:           blk.39.ffn_gate.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  357:             blk.39.ffn_up.weight f16      [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  358:           blk.39.ffn_down.weight f16      [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  359:          blk.39.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  360:           blk.39.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  361:               output_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  362:                    output.weight f16      [  5120, 32000,     1,     1 ]
# llama_model_loader: - kv   0:                       general.architecture str
# llama_model_loader: - kv   1:                               general.name str
# llama_model_loader: - kv   2:                       llama.context_length u32
# llama_model_loader: - kv   3:                     llama.embedding_length u32
# llama_model_loader: - kv   4:                          llama.block_count u32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32
# llama_model_loader: - kv   7:                 llama.attention.head_count u32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32
# llama_model_loader: - kv  10:                          general.file_type u32
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32
# llama_model_loader: - kv  17:            tokenizer.ggml.padding_token_id u32
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type  f16:  282 tensors
# llama_model_quantize_internal: meta size = 745344 bytes
# [   1/ 363]                    token_embd.weight - [ 5120, 32000,     1,     1], type =    f16, quantizing to q2_K .. size =   312.50 MB ->    51.27 MB | hist:
# [   2/ 363]                  blk.0.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [   3/ 363]                  blk.0.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [   4/ 363]                  blk.0.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [   5/ 363]             blk.0.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [   6/ 363]                blk.0.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [   7/ 363]                  blk.0.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [   8/ 363]                blk.0.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [   9/ 363]               blk.0.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  10/ 363]                blk.0.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  11/ 363]                  blk.1.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [  12/ 363]                  blk.1.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [  13/ 363]                  blk.1.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [  14/ 363]             blk.1.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [  15/ 363]                blk.1.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  16/ 363]                  blk.1.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  17/ 363]                blk.1.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  18/ 363]               blk.1.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  19/ 363]                blk.1.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  20/ 363]                  blk.2.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [  21/ 363]                  blk.2.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [  22/ 363]                  blk.2.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [  23/ 363]             blk.2.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [  24/ 363]                blk.2.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  25/ 363]                  blk.2.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  26/ 363]                blk.2.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  27/ 363]               blk.2.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  28/ 363]                blk.2.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  29/ 363]                  blk.3.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [  30/ 363]                  blk.3.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [  31/ 363]                  blk.3.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [  32/ 363]             blk.3.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [  33/ 363]                blk.3.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  34/ 363]                  blk.3.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  35/ 363]                blk.3.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  36/ 363]               blk.3.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  37/ 363]                blk.3.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  38/ 363]                  blk.4.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [  39/ 363]                  blk.4.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [  40/ 363]                  blk.4.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [  41/ 363]             blk.4.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [  42/ 363]                blk.4.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  43/ 363]                  blk.4.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  44/ 363]                blk.4.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [  45/ 363]               blk.4.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# ...
# [ 253/ 363]               blk.27.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 254/ 363]                 blk.28.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 255/ 363]                 blk.28.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 256/ 363]                 blk.28.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 257/ 363]            blk.28.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 258/ 363]               blk.28.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 259/ 363]                 blk.28.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 260/ 363]               blk.28.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 261/ 363]              blk.28.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 262/ 363]               blk.28.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 263/ 363]                 blk.29.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 264/ 363]                 blk.29.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 265/ 363]                 blk.29.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 266/ 363]            blk.29.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 267/ 363]               blk.29.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 268/ 363]                 blk.29.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 269/ 363]               blk.29.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 270/ 363]              blk.29.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 271/ 363]               blk.29.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 272/ 363]                 blk.30.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 273/ 363]                 blk.30.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 274/ 363]                 blk.30.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 275/ 363]            blk.30.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 276/ 363]               blk.30.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 277/ 363]                 blk.30.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 278/ 363]               blk.30.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 279/ 363]              blk.30.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 280/ 363]               blk.30.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 281/ 363]                 blk.31.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 282/ 363]                 blk.31.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 283/ 363]                 blk.31.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 284/ 363]            blk.31.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 285/ 363]               blk.31.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 286/ 363]                 blk.31.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 287/ 363]               blk.31.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 288/ 363]              blk.31.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 289/ 363]               blk.31.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 290/ 363]                 blk.32.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 291/ 363]                 blk.32.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 292/ 363]                 blk.32.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 293/ 363]            blk.32.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 294/ 363]               blk.32.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 295/ 363]                 blk.32.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 296/ 363]               blk.32.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 297/ 363]              blk.32.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 298/ 363]               blk.32.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 299/ 363]                 blk.33.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 300/ 363]                 blk.33.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 301/ 363]                 blk.33.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 302/ 363]            blk.33.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 303/ 363]               blk.33.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 304/ 363]                 blk.33.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 305/ 363]               blk.33.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 306/ 363]              blk.33.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 307/ 363]               blk.33.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 308/ 363]                 blk.34.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 309/ 363]                 blk.34.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 310/ 363]                 blk.34.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 311/ 363]            blk.34.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 312/ 363]               blk.34.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 313/ 363]                 blk.34.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 314/ 363]               blk.34.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 315/ 363]              blk.34.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 316/ 363]               blk.34.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 317/ 363]                 blk.35.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 318/ 363]                 blk.35.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 319/ 363]                 blk.35.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 320/ 363]            blk.35.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 321/ 363]               blk.35.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 322/ 363]                 blk.35.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 323/ 363]               blk.35.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 324/ 363]              blk.35.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 325/ 363]               blk.35.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 326/ 363]                 blk.36.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 327/ 363]                 blk.36.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 328/ 363]                 blk.36.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 329/ 363]            blk.36.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 330/ 363]               blk.36.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 331/ 363]                 blk.36.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 332/ 363]               blk.36.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 333/ 363]              blk.36.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 334/ 363]               blk.36.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 335/ 363]                 blk.37.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 336/ 363]                 blk.37.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 337/ 363]                 blk.37.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 338/ 363]            blk.37.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 339/ 363]               blk.37.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 340/ 363]                 blk.37.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 341/ 363]               blk.37.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 342/ 363]              blk.37.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 343/ 363]               blk.37.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 344/ 363]                 blk.38.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 345/ 363]                 blk.38.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 346/ 363]                 blk.38.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 347/ 363]            blk.38.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 348/ 363]               blk.38.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 349/ 363]                 blk.38.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 350/ 363]               blk.38.ffn_down.weight - [13824,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 351/ 363]              blk.38.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 352/ 363]               blk.38.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 353/ 363]                 blk.39.attn_q.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 354/ 363]                 blk.39.attn_k.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q2_K .. size =    50.00 MB ->     8.20 MB | hist:
# [ 355/ 363]                 blk.39.attn_v.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 356/ 363]            blk.39.attn_output.weight - [ 5120,  5120,     1,     1], type =    f16, quantizing to q3_K .. size =    50.00 MB ->    10.74 MB | hist:
# [ 357/ 363]               blk.39.ffn_gate.weight - [ 5120, 13824,     1,     1], type =    f16, quantizing to q3_K .. size =   135.00 MB ->    29.00 MB | hist:
# [ 358/ 363]                 blk.39.ffn_up.weight - [ 5120, 13824,     1,     1], type =    f16,
